# %%
import pandas as pd
import numpy as np

# %%
csv_path_1 = "C:/Users/mattm/pandas-challenge/raw_data/schools_complete.csv"
csv_path_2 = "C:/Users/mattm/pandas-challenge/raw_data/students_complete.csv"

schools_df = pd.read_csv(csv_path_1, encoding="utf-8")
students_df = pd.read_csv(csv_path_2, encoding="utf-8")
schools_df = schools_df.rename(columns={'name': 'school'})
schools_df
# Out:
#     School ID                 school      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
total_schools = schools_df["school"].count()

total_students = schools_df["size"].sum()

total_budget = schools_df["budget"].sum()

average_math = students_df["math_score"].mean()

average_reading = students_df["reading_score"].mean()

amount_passing_math = students_df[students_df["math_score"] >= 70].count()["math_score"]
percent_passing_math = (100 * amount_passing_math) / total_students

amount_passing_reading = students_df[students_df["reading_score"] >= 70].count()["reading_score"]
percent_passing_reading = (100 * amount_passing_reading) / total_students

total_passing = amount_passing_math + amount_passing_reading
percent_passing_total = (percent_passing_math + percent_passing_reading) / 2

# %%
school_table_data = {"Total Schools": total_schools, "Total Students": total_students, "Total Budget": total_budget, "Average Math Score": average_math, "Average Reading Score": average_reading, "% Passing Math": percent_passing_math, "% Passing Reading": percent_passing_reading, "Overall Passing Rate": percent_passing_total}
school_table = pd.DataFrame([school_table_data])
school_table = school_table[["Total Schools", "Total Students", "Total Budget", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]
school_table
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    Overall Passing Rate
# 0             80.393158

# %%
school_table["Total Students"] = school_table["Total Students"].map("{:,}".format)
school_table["Total Budget"] = school_table["Total Budget"].map("${:,.2f}".format)
school_table
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    Overall Passing Rate
# 0             80.393158

# %%
students_df["Passing Math"] = np.where(students_df["math_score"] >= 70, 1, 0)
students_df["Passing Reading"] = np.where(students_df["reading_score"] >= 70, 1, 0)
students_df["Total Passing"]= (students_df["Passing Math"] + students_df["Passing Reading"]) / 2

# %%
students_df_2 = students_df[["school", "Passing Math", "Passing Reading", "Total Passing"]]
students_df_2_group = students_df_2.groupby(["school"])
students_df_2_group_sum = students_df_2_group.sum()

# %%
total_by_school = schools_df[["school", "type", "size", "budget"]]
total_by_school_group = total_by_school.groupby(["school"])
total_comparison = total_by_school_group.sum()

# %%
school_merge = school_score_comparison.join(total_comparison)

# %%
school_merge["Per Student Budget"] = school_merge["budget"] / school_merge["size"]

# %%
school_merge_2 = school_merge.join(students_df_2_group_sum)

# %%
school_merge_2["% Passing Math"] = (100 * school_merge_2["Passing Math"]) / school_merge_2["size"]
school_merge_2["% Passing Reading"] = (100 * school_merge_2["Passing Reading"]) / school_merge_2["size"]
school_merge_2["Overall Passing Rate"] = (100 * school_merge_2["Total Passing"]) / school_merge_2["size"]
school_merge_2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'size'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-269-5e88f070bae9> in <module>()
# ...

# %%
school_merge_2.rename(columns={"size": "Total Students", "budget": "Total Student Budget", "math_score": "Average Math Score", "reading_score": "Average Reading Score", "Overall Passing Rate": "% Overall Passing Rate"}, inplace=True)
school_merge_3 = school_merge_2.drop(["Passing Math", "Passing Reading", "Total Passing"], axis=1)
school_merge_3
# Out:
#                        Average Reading Score  Average Math Score  \
# school
# Bailey High School                 81.033963           77.048432
# Cabrera High School                83.975780           83.061895
# Figueroa High School               81.158020           76.711767
# Ford High School                   80.746258           77.102592
# Griffin High School                83.816757           83.351499
# Hernandez High School              80.934412           77.289752
# Holden High School                 83.814988           83.803279
# Huang High School                  81.182722           76.629414
# Johnson High School                80.966394           77.072464
# Pena High School                   84.044699           83.839917
# Rodriguez High School              80.744686           76.842711
# Shelton High School                83.725724           83.359455
# Thomas High School                 83.848930           83.418349
# ...

# %%
school_merge_3["Total Student Budget"] = school_merge_3["Total Student Budget"].map("${:,.2f}".format)
school_merge_3["Per Student Budget"] = school_merge_3["Per Student Budget"].map("${:,.2f}".format)
school_merge_3
# Out:
#                        Average Reading Score  Average Math Score  \
# school
# Bailey High School                 81.033963           77.048432
# Cabrera High School                83.975780           83.061895
# Figueroa High School               81.158020           76.711767
# Ford High School                   80.746258           77.102592
# Griffin High School                83.816757           83.351499
# Hernandez High School              80.934412           77.289752
# Holden High School                 83.814988           83.803279
# Huang High School                  81.182722           76.629414
# Johnson High School                80.966394           77.072464
# Pena High School                   84.044699           83.839917
# Rodriguez High School              80.744686           76.842711
# Shelton High School                83.725724           83.359455
# Thomas High School                 83.848930           83.418349
# ...

# %%
top_performing_schools = school_merge_3.sort_values("% Overall Passing Rate", ascending=False)
top_performing_schools.head(5)
# Out:
#                      Average Reading Score  Average Math Score  \
# school
# Cabrera High School              83.975780           83.061895
# Thomas High School               83.848930           83.418349
# Pena High School                 84.044699           83.839917
# Griffin High School              83.816757           83.351499
# Wilson High School               83.989488           83.274201
#
#                      Total Students Total Student Budget Per Student Budget  \
# school
# Cabrera High School            1858        $1,081,356.00            $582.00
# Thomas High School             1635        $1,043,130.00            $638.00
# Pena High School                962          $585,858.00            $609.00
# Griffin High School            1468          $917,500.00            $625.00
# Wilson High School             2283        $1,319,574.00            $578.00
#
#                      % Passing Math  % Passing Reading  % Overall Passing Rate
# school
# ...

# %%
bottom_performing_schools = school_merge_3.sort_values("% Overall Passing Rate", ascending=True)
bottom_performing_schools.head(5)
# Out:
#                        Average Reading Score  Average Math Score  \
# school
# Rodriguez High School              80.744686           76.842711
# Figueroa High School               81.158020           76.711767
# Huang High School                  81.182722           76.629414
# Johnson High School                80.966394           77.072464
# Ford High School                   80.746258           77.102592
#
#                        Total Students Total Student Budget Per Student Budget  \
# school
# Rodriguez High School            3999        $2,547,363.00            $637.00
# Figueroa High School             2949        $1,884,411.00            $639.00
# Huang High School                2917        $1,910,635.00            $655.00
# Johnson High School              4761        $3,094,650.00            $650.00
# Ford High School                 2739        $1,763,916.00            $644.00
#
#                        % Passing Math  % Passing Reading  \
# school
# ...

# %%
grade_data = {"School": students_df["school"], "math score": students_df["math_score"], "grade": students_df["grade"]}
grade_df = pd.DataFrame(grade_data)
grade_df.head()
# Out:
#               School grade  math score
# 0  Huang High School   9th          79
# 1  Huang High School  12th          61
# 2  Huang High School  12th          60
# 3  Huang High School  12th          58
# 4  Huang High School   9th          84
